# %%
import numpy as np
import matplotlib.pylab as plt
#import pandas as pd
import os
from scipy.optimize import curve_fit

# %%
frecuencia=1
Vout=np.genfromtxt('/home/codorso/Escritorio/datos/triangular/ALL0001/F0001CH1.CSV', delimiter=',',usecols = (3, 4))

# %%
plt.plot(Vout[200:2300,0],Vout[200:2300,1])

# %%
Vout2=Vout[200:2300,0]
Vout3=Vout[200:2300,1]

# %%
len(Vout2)
# Out:
# 2100

# %%
i=int(np.where(Vout2==Vout2[Vout3==min(Vout3)])[0])
Vout_f=Vout3[i+1:i+1001]

# %%
np.shape(Vout_f)
# Out:
# (1000,)

# %%
plt.figure(figsize=(15,10))
plt.plot(Vin[:500],Vout_f[:500], 'r')
plt.plot(Vin[500:],Vout_f[500:], 'b')

# %%
np.diff(Vout[:,0])
# Out:
# array([0.001, 0.001, 0.001, ..., 0.001, 0.001, 0.001])

# %%
tiempo=np.linspace(0,1,1000)
Vin_ida=np.linspace(-0.5,0.498,500)
Vin_vuelta=np.linspace(0.5,-0.498,500)
Vin=np.concatenate((Vin_ida,Vin_vuelta))

# %%
plt.plot(tiempo,Vin)

# %%
i=int(np.where(Vout2==Vout2[Vout3==min(Vout3)])[0])
Vout_f=Vout3[i+30:i+1030]
plt.figure(figsize=(15,10))
plt.plot(Vin[:500],Vout_f[:500], 'r')
plt.plot(Vin[500:],Vout_f[500:], 'b')

# %%
i=int(np.where(Vout2==Vout2[Vout3==min(Vout3)])[0])
Vout_f=Vout3[i-7:i+1000-7]
plt.figure(figsize=(15,10))
plt.plot(Vin[:500],Vout_f[:500], 'r')
plt.plot(Vin[500:],Vout_f[500:], 'b')
