# %%
import numpy as np
import matplotlib.pylab as plt
#import pandas as pd
import os
from scipy.optimize import curve_fit

# %%
i=np.arange(0,10)
k=np.arange(10,87)
frecuencia=1000*np.genfromtxt('/home/codorso/Escritorio/datos/0gr/frecs', delimiter=',')

# %%
# Out:
# array([1.00e+01, 1.50e+01, 1.60e+01, 1.70e+01, 2.00e+01, 2.50e+01,
#        3.00e+01, 3.50e+01, 4.00e+01, 4.50e+01, 5.00e+01, 6.50e+01,
#        8.00e+01, 1.00e+02, 1.50e+02, 2.00e+02, 2.50e+02, 3.00e+02,
#        3.50e+02, 4.00e+02, 4.50e+02, 5.00e+02, 5.50e+02, 6.00e+02,
#        6.50e+02, 7.00e+02, 7.50e+02, 8.00e+02, 8.50e+02, 9.00e+02,
#        9.30e+02, 9.60e+02, 9.90e+02, 1.00e+03, 1.05e+03, 1.08e+03,
#        1.10e+03, 1.15e+03, 1.20e+03, 1.25e+03, 1.30e+03, 1.35e+03,
#        1.40e+03, 1.45e+03, 1.50e+03, 1.55e+03, 1.60e+03, 1.65e+03,
#        1.70e+03, 1.75e+03, 1.80e+03, 1.85e+03, 1.90e+03, 1.95e+03,
#        2.00e+03, 2.05e+03, 2.10e+03, 2.15e+03, 2.20e+03, 2.25e+03,
#        2.30e+03, 2.40e+03, 2.50e+03, 2.60e+03, 2.70e+03, 2.80e+03,
#        2.90e+03, 3.00e+03, 4.00e+03, 5.00e+03, 6.00e+03, 7.00e+03,
#        8.00e+03, 9.00e+03, 1.00e+04, 1.10e+04, 1.20e+04, 1.30e+04,
#        1.40e+04, 1.50e+04, 1.60e+04, 1.70e+04, 1.80e+04, 1.90e+04,
#        2.10e+04, 2.20e+04, 2.50e+04])

# %%
seno=[]
for j in i:
    #seno.append(np.genfromtxt('/home/josefina/Desktop/Datos0/ALL000{}/F000{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))
    #seno.append(np.genfromtxt("C:\\Users\\pc\\Downloads\\Labo6y7\\Senoidal\\ALL000{}\\F000{}CH1.CSV".format(j,j), delimiter=',',usecols = (3, 4)))
    seno.append(np.genfromtxt('/home/codorso/Escritorio/datos/0gr/ALL000{}/F000{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))
    
for j in k:
    #seno.append(np.genfromtxt('/home/josefina/Desktop/Datos0/ALL00{}/F00{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))
    #seno.append(np.genfromtxt("C:\\Users\\pc\\Downloads\\Labo6y7\\Senoidal\\ALL00{}\\F00{}CH1.CSV".format(j,j), delimiter=',',usecols = (3, 4)))
    seno.append(np.genfromtxt('/home/codorso/Escritorio/datos/0gr/ALL00{}/F00{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))

# %%
len(seno)
# Out:
# 87

# %%
plt.figure(figsize=(15,20))
for j in i:
    plt.subplot(5,2,j+1)
    plt.plot(seno[j][:,0],seno[j][:,1])
    
plt.show()

# %%
f_sin = lambda x, A, B, C, D: A * np.sin(B*x+C)+D

# Ajustamos, pero con las funciónes logaritmicas. Usamos propagación de errores
def ajusteseno(datos,po):
    popt_sin, pcov_sin = curve_fit(f_sin, datos[:,0], datos[:,1], sigma = 0.005*np.ones(len(datos[:,1])), absolute_sigma=True,p0=po) #po mi parametros iniciales que a ojo yo veo que son. por default son 1.
    return(popt_sin, pcov_sin)

# %%
plt.plot(seno[20][:,0],seno[20][:,1])
frecuencia[20]
# Out:
# 450.0

# %%
popt_sin, pcov_sin=ajusteseno(seno[30],po=[0.4,2*np.pi*frecuencia[30],0,0])
popt_sin
print (pcov_sin[0])
# Out:
# [ 8.23590010e+06 -7.52949086e+10 -1.61255582e+02  3.62630899e+02]

# %%
l=np.arange(0,87)
A=[]
Aperr=[]
plt.figure(figsize=(15,50))
for j in l:
    popt_sin, pcov_sin=ajusteseno(seno[j],po=[0.7,2*np.pi*frecuencia[j],0.04,0])
    A.append(popt_sin[0])
    Aperr.append(np.sqrt(pcov_sin[0,0])) #CHEQUEAR si no entendí mal, este sería el error de la amplitud
    plt.subplot(18,5,j+1)
    plt.plot(seno[j][:,0],seno[j][:,1])
    plt.plot(seno[j][:,0],popt_sin[0] * np.sin(popt_sin[1]*seno[j][:,0]+popt_sin[2])+popt_sin[3])

plt.show()

# %%
plt.figure(figsize=(10,7))
plt.errorbar(frecuencia,np.abs(A),Aperr, fmt= '.-', ecolor='r', )#,'.-')
plt.semilogx()
plt.grid()
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Amplitud (V)')
plt.title('Curva barrido con sinusoidal')
#plt.savefig('Calibr_A_sen.png')
plt.show()

# %%
Vpp = 2.0*np.abs(A)
errVpp = np.sqrt(2)*np.abs(Aperr)

plt.figure(figsize=(10,7))
plt.errorbar(frecuencia, Vpp, errVpp, fmt= '.-', ecolor='r')#, )#,'.-')
plt.semilogx()
plt.grid()
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Vpp (V)')
plt.title('Curva barrido con sinusoidal')
#plt.savefig('Calibr_Vpp_sen.png')
plt.show()

# %%
i=np.arange(0,10)
k=np.arange(10,36)
frecuenciaB=1000*np.genfromtxt('/home/codorso/Escritorio/datos/2gr/frec_2g', delimiter=',')
senoB=[]
for j in i:
    #seno.append(np.genfromtxt('/home/josefina/Desktop/Datos0/ALL000{}/F000{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))
    #seno.append(np.genfromtxt("C:\\Users\\pc\\Downloads\\Labo6y7\\Senoidal\\ALL000{}\\F000{}CH1.CSV".format(j,j), delimiter=',',usecols = (3, 4)))
    senoB.append(np.genfromtxt('/home/codorso/Escritorio/datos/2gr/ALL000{}/F000{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))
    
for j in k:
    #seno.append(np.genfromtxt('/home/josefina/Desktop/Datos0/ALL00{}/F00{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))
    #seno.append(np.genfromtxt("C:\\Users\\pc\\Downloads\\Labo6y7\\Senoidal\\ALL00{}\\F00{}CH1.CSV".format(j,j), delimiter=',',usecols = (3, 4)))
    senoB.append(np.genfromtxt('/home/codorso/Escritorio/datos/2gr/ALL00{}/F00{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))

# %%
l=np.arange(0,36)
B=[]
Bperr=[]
plt.figure(figsize=(15,30))
for j in l:
    popt_sin, pcov_sin=ajusteseno(senoB[j],po=[0.2,2*np.pi*frecuenciaB[j],0.04,0])
    B.append(popt_sin[0])
    Bperr.append(np.sqrt(pcov_sin[0,0])) #CHEQUEAR si no entendí mal, este sería el error de la amplitud
    plt.subplot(9,4,j+1)
    plt.plot(senoB[j][:,0],senoB[j][:,1])
    plt.plot(senoB[j][:,0],popt_sin[0] * np.sin(popt_sin[1]*senoB[j][:,0]+popt_sin[2])+popt_sin[3])

plt.show()

# %%
plt.figure(figsize=(10,7))
plt.errorbar(frecuencia,np.abs(A),Aperr, fmt= '.-', ecolor='b', label='vacío')#,'.-')
plt.errorbar(frecuenciaB,np.abs(B),Bperr, fmt= 'r.-', ecolor='r', label='2 gramos')#,'.-')
plt.semilogx()
plt.grid()
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Amplitud (V)')
plt.title('Curva barrido con sinusoidal')
plt.legend()
#plt.savefig('Calibr_A_sen.png')
plt.show()

# %%
i=np.arange(0,10)
k=np.arange(10,37)
frecuenciaC=1000*np.genfromtxt('/home/codorso/Escritorio/datos/4gr/frec_4g', delimiter=',')
senoC=[]
for j in i:
    #seno.append(np.genfromtxt('/home/josefina/Desktop/Datos0/ALL000{}/F000{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))
    #seno.append(np.genfromtxt("C:\\Users\\pc\\Downloads\\Labo6y7\\Senoidal\\ALL000{}\\F000{}CH1.CSV".format(j,j), delimiter=',',usecols = (3, 4)))
    senoC.append(np.genfromtxt('/home/codorso/Escritorio/datos/4gr/ALL000{}/F000{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))
    
for j in k:
    #seno.append(np.genfromtxt('/home/josefina/Desktop/Datos0/ALL00{}/F00{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))
    #seno.append(np.genfromtxt("C:\\Users\\pc\\Downloads\\Labo6y7\\Senoidal\\ALL00{}\\F00{}CH1.CSV".format(j,j), delimiter=',',usecols = (3, 4)))
    senoC.append(np.genfromtxt('/home/codorso/Escritorio/datos/4gr/ALL00{}/F00{}CH1.CSV'.format(j,j), delimiter=',',usecols = (3, 4)))

# %%
l=np.arange(0,37)
C=[]
Cperr=[]
plt.figure(figsize=(15,30))
for j in l:
    popt_sin, pcov_sin=ajusteseno(senoC[j],po=[0.2,2*np.pi*frecuenciaC[j],0.04,0])
    C.append(popt_sin[0])
    Cperr.append(np.sqrt(pcov_sin[0,0])) #CHEQUEAR si no entendí mal, este sería el error de la amplitud
    plt.subplot(10,4,j+1)
    plt.plot(senoC[j][:,0],senoC[j][:,1])
    plt.plot(senoC[j][:,0],popt_sin[0] * np.sin(popt_sin[1]*senoC[j][:,0]+popt_sin[2])+popt_sin[3])

plt.show()

# %%
plt.figure(figsize=(10,7))
plt.errorbar(frecuencia,np.abs(A),Aperr, fmt= '.-', ecolor='b', label='vacío')#,'.-')
plt.errorbar(frecuenciaB,np.abs(B),Bperr, fmt= 'r.-', ecolor='r', label='2 gramos')#,'.-')
plt.errorbar(frecuenciaC,np.abs(C),Cperr, fmt= 'g.-', ecolor='g', label='4 gramos')#,'.-')
plt.semilogx()
plt.grid()
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Amplitud (V)')
plt.title('Curva barrido con sinusoidal')
plt.legend()
#plt.savefig('Calibr_masas.png')

plt.show()
